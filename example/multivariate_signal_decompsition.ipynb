# %%
from pysdkit.data import test_multivariate_signal
from pysdkit.plot import plot_signal, plot_IMFs

time, signal = test_multivariate_signal(case=2)
fig = plot_signal(time, signal)

# %%
from pysdkit import MEMD, MVMD

memd = MEMD()
results = memd.fit_transform(signal)
# Out:
# (1000, 4)
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
plot_IMFs(signal, results)
